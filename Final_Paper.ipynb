# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanErm/mlproject/blob/main/Final_Paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Abstract
#
# Our study focused on comparing the race of victims against each other, narrowing it down to analyze potential changes over the time period leading up to COVID-19 and the years after to investigate a potential link between the pandemic, and increase in hate crimes to see whether or not there’s a causal link between the pandemic and changes in crime rate, frequency and targets. To explore this, we used crime data compiled through different sources, like the FBI, containing murders throughout the United States from 1976 to 2023. For this analysis question, the year range was narrowed down to start from 2016. It contained data about what state and city the crime took place, what the data source is, when it happened, the nature of the homicide, including the situation, weapon & victim count, victim’s age, race, sex & ethnicity, as well as the offender’s age, sex & race.
#
# Using this data set, a decision tree was created using factors of year, offender age, month, state, offender race, and situation to predict the victim’s race for murder and non-negligent manslaughter to train a model and predict the victim’s race. Several comparisons were made, comparing white v. black victim, Asian v. white, Asian v. black, and Asian v. Native American or Alaskan Native. The decision tree made the most incorrect predictions when compared to white victims, no matter which combination, likely because the large proportion of victims is white among all data observations.
#
# Another model was created comparing COVID-19 cases with the crime data set, starting from 2020-2023, filtering for crimes against Asian individuals. The results only had data in California, Arizona, Alaska, Alabama, and Arkansas. There does not appear to be a trend when comparing the graphs of COVID-19 cases across the 4 years v. crimes against Asian individuals over the 4 years among these 5 states, meaning there is likely neither a correlation nor causation that can be concluded between COVID-19 and the frequency of Asian hate crimes.

# %% [markdown]
# # Introduction

# %% [markdown]
# # Data

# %% [markdown]
# ### Crime dataset used
#
# This dataset was includes data starting from 2016.

# %%
import pandas as pd

pd.read_csv('https://raw.githubusercontent.com/jac7az/mlproject/refs/heads/main/cleaned_df.csv')
# Out:
#        Unnamed: 0       State      Agency Source Solved  Year     Month  \
# 0             738      Alaska   Anchorage    FBI    Yes  2016   January
# 1             739      Alaska   Anchorage    FBI    Yes  2016   January
# 2             740      Alaska   Anchorage    FBI    Yes  2016   January
# 3             741      Alaska   Anchorage    FBI    Yes  2016   January
# 4             742      Alaska   Anchorage    FBI    Yes  2016   January
# ...           ...         ...         ...    ...    ...   ...       ...
# 13789       88211  California  Long Beach    FBI    Yes  2023  November
# 13790       88212  California  Long Beach    FBI     No  2023  November
# 13791       88213  California  Long Beach    FBI    Yes  2023  December
# 13792       88214  California  Long Beach    FBI    Yes  2023  December
# 13793       88215  California  Long Beach    FBI     No  2023  December
#
#                                     Homicide  \
# 0                 Manslaughter by negligence
# 1      Murder and non-negligent manslaughter
# 2      Murder and non-negligent manslaughter
# 3      Murder and non-negligent manslaughter
# 4      Murder and non-negligent manslaughter
# ...                                      ...
# 13789  Murder and non-negligent manslaughter
# 13790  Murder and non-negligent manslaughter
# 13791  Murder and non-negligent manslaughter
# 13792  Murder and non-negligent manslaughter
# 13793  Murder and non-negligent manslaughter
#
#                                Situation  VicAge  ...  \
# 0          Single victim/single offender     2.0  ...
# 1       Multiple victims/single offender    40.0  ...
# 2       Multiple victims/single offender    18.0  ...
# 3       Single victim/multiple offenders    49.0  ...
# 4          Single victim/single offender    32.0  ...
# ...                                  ...     ...  ...
# 13789      Single victim/single offender    41.0  ...
# 13790  Single victim/unknown offender(s)    58.0  ...
# 13791      Single victim/single offender     5.0  ...
# 13792      Single victim/single offender    36.0  ...
# 13793   Single victim/multiple offenders    28.0  ...
#
#                                  VicRace               VicEthnic OffAge  \
# 0      American Indian or Alaskan Native                     NaN   21.0
# 1                                  White                     NaN   15.0
# 2                                  White                     NaN   15.0
# 3      American Indian or Alaskan Native                     NaN   34.0
# 4      American Indian or Alaskan Native                     NaN   33.0
# ...                                  ...                     ...    ...
# 13789                              Black  Not of Hispanic origin    NaN
# 13790                              Black  Not of Hispanic origin    NaN
# 13791                                NaN         Hispanic origin   39.0
# 13792                              Black                     NaN    NaN
# 13793                              White         Hispanic origin    NaN
#
#        OffSex                            OffRace               OffEthnic  \
# 0      Female  American Indian or Alaskan Native                     NaN
# 1        Male                              White                     NaN
# 2        Male                              White                     NaN
# 3        Male                              White                     NaN
# 4        Male  American Indian or Alaskan Native                     NaN
# ...       ...                                ...                     ...
# 13789    Male                              Black  Not of Hispanic origin
# 13790     NaN                                NaN                     NaN
# 13791    Male                              Black  Not of Hispanic origin
# 13792    Male                                NaN                     NaN
# 13793     NaN                                NaN                     NaN
#
#         Weapon       Relationship VicCount  OffCount
# 0      Firearm          Offspring      0.0       0.0
# 1      Firearm            Sibling      1.0       0.0
# 2      Firearm            Sibling      1.0       0.0
# 3      Firearm              Other      0.0       1.0
# 4        Other  Romantic Relation      0.0       0.0
# ...        ...                ...      ...       ...
# 13789  Firearm                NaN      0.0       0.0
# 13790    Other                NaN      0.0       0.0
# 13791  Firearm          Offspring      0.0       0.0
# 13792  Firearm                NaN      0.0       0.0
# 13793  Firearm                NaN      0.0       1.0
#
# [13794 rows x 21 columns]

# %% [markdown]
# ### Monthly Covid cases by state dataset

# %%
pd.read_csv('https://raw.githubusercontent.com/jac7az/mlproject/refs/heads/main/cases_month_state.csv')
# Out:
#       Unnamed: 0 state  month_number  new_cases
# 0              0    AK             1          0
# 1              1    AK             2          0
# 2              2    AK             3         63
# 3              3    AK             4        292
# 4              4    AK             5         72
# ...          ...   ...           ...        ...
# 2455        2455    WY            37        919
# 2456        2456    WY            38       1068
# 2457        2457    WY            39       1246
# 2458        2458    WY            40        544
# 2459        2459    WY            41        495
#
# [2460 rows x 4 columns]

# %% [markdown]
# # Pre-Analysis Plan
